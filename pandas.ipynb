# %% [markdown]
# ## Часть 1: Введение в Pandas
#
# Pandas - это библиотека Python для работы с данными. Она предоставляет мощные инструменты для анализа и манипуляции данными.
#
# ### Установка Pandas
#
# Для начала убедитесь, что у вас установлена библиотека Pandas. Если ее нет, установите ее с помощью команды:

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\programs\visualstudioprojects\pplabs\lab2\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\programs\visualstudioprojects\pplabs\lab2\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programs\visualstudioprojects\pplabs\lab2\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\programs\visualstudioprojects\pplabs\lab2\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\programs\visualstudioprojects\pplabs\lab2\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\programs\visualstudioprojects\pplabs\lab2\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Импорт библиотеки
# Давайте начнем с импорта библиотеки Pandas:

# %%
import pandas as pd

# %% [markdown]
# ## Часть 2: Работа с данными
# ### Чтение данных
# Мы будем использовать датасет Titanic. Давайте прочитаем данные из CSV файла.

# %%
# Чтение данных из файла 'titanic.csv'
# Используйте метод pd.read_csv()
table = pd.read_csv('titanic.csv')

# %% [markdown]
# ### Предпросмотр данных
# Для первого ознакомления с данными давайте выведем первые несколько строк.

# %%
# Вывод первых 5 строк данных
# Используйте метод .head()
print(table.head(5))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Информация о данных
# Чтобы получить общую информацию о данных, воспользуйтесь методом .info().

# %%
print(table.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %% [markdown]
# ### Работа с NaN
# Часто данные содержат пропущенные значения, которые представляются как NaN (Not a Number). Pandas предоставляет удобные методы для работы с ними.
#
# Проверка на наличие NaN. Методы fillna и dropna возвращают новые Dataframe, проверьте нет ли в них NaN

# %%
# Проверка на наличие NaN в DataFrame
# Используйте метод .isna()
print(table.isna())
print(table.fillna(0).isna())
print(table.dropna().isna())
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False  False     False
# 1    False  False     False
# 2    False  False     False
# 3    False  False     False
# 4    False  False     False
# ..     ...    ...       ...
# 886  False  False     False
# 887  False  False     False
# 888  False  False     False
# 889  False  False     False
# 890  False  False     False
#
# [891 rows x 12 columns]
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 1          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# 11         False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 871        False     False   False  False  False  False  False  False   False
# 872        False     False   False  False  False  False  False  False   False
# 879        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 1    False  False     False
# 3    False  False     False
# 6    False  False     False
# 10   False  False     False
# 11   False  False     False
# ..     ...    ...       ...
# 871  False  False     False
# 872  False  False     False
# 879  False  False     False
# 887  False  False     False
# 889  False  False     False
#
# [183 rows x 12 columns]

# %% [markdown]
# Заполнение NaN

# %%
# Заполнение NaN определенным значением (например, нулем)
# Используйте метод .fillna()
table = table.fillna(0)

# %% [markdown]
# Удаление строк с NaN

# %%
# Удаление строк, содержащих NaN
# Используйте метод .dropna()
table = table.dropna()

# %% [markdown]
# ## Часть 3: Обработка DataFrame
# ### Выбор данных
# Pandas позволяет выбирать данные по индексам, меткам столбцов и условиям.

# %%
# Выбор столбца по метке
# Используйте синтаксис DataFrame['название_столбца']
age_column = table['Age']
print(age_column.head())

# Выбор нескольких столбцов
# Используйте синтаксис DataFrame[['столбец_1', 'столбец_2']]
subset = table[['Name', 'Age', 'Sex']]
print(subset.head())

# Выбор строк по индексу
# Используйте метод .loc[]
rows = table.loc[10:14]
print(rows)

# Выбор строк и столбцов по условию
# Используя логические операции, выберите мужчин старше 30
men_over_30 = table[(table['Sex'] == 'male') & (table['Age'] > 30)]
print(men_over_30.head())
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000    G6        S
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500     0        S
# 13    male  39.0      1      5     347082  31.2750     0        S
# 14  female  14.0      0      0     350406   7.8542     0        S
#     PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 4             5         0       3     Allen, Mr. William Henry  male  35.0
# 6             7         0       1      McCarthy, Mr. Timothy J  male  54.0
# 13           14         0       3  Andersson, Mr. Anders Johan  male  39.0
# 20           21         0       2         Fynney, Mr. Joseph J  male  35.0
# 21           22         1       2        Beesley, Mr. Lawrence  male  34.0
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 4       0      0  373450   8.0500     0        S
# 6       0      0   17463  51.8625   E46        S
# 13      1      5  347082  31.2750     0        S
# 20      0      0  239865  26.0000     0        S
# 21      0      0  248698  13.0000   D56        S

# %% [markdown]
# ### Сортировка данных
# Сортировка данных по значениям столбцов.

# %%
# Сортировка данных по столбцу 'столбец_1' по возрастанию
# Используйте метод .sort_values()
table = table.sort_values('Age')
print(table)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 863          864         0       3     Sage, Miss. Dorothy Edith "Dolly"
# 711          712         0       1                    Klaber, Mr. Herman
# 718          719         0       3                   McEvoy, Mr. Michael
# 256          257         1       1        Thorne, Mrs. Gertrude Maybelle
# 727          728         1       3              Mannion, Miss. Margareth
# ..           ...       ...     ...                                   ...
# 116          117         0       3                  Connors, Mr. Patrick
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 863  female   0.0      8      2  CA. 2343  69.5500     0        S
# 711    male   0.0      0      0    113028  26.5500  C124        S
# 718    male   0.0      0      0     36568  15.5000     0        Q
# 256  female   0.0      0      0  PC 17585  79.2000     0        C
# 727  female   0.0      0      0     36866   7.7375     0        Q
# ..      ...   ...    ...    ...       ...      ...   ...      ...
# 116    male  70.5      0      0    370369   7.7500     0        Q
# 96     male  71.0      0      0  PC 17754  34.6542    A5        C
# 493    male  71.0      0      0  PC 17609  49.5042     0        C
# 851    male  74.0      0      0    347060   7.7750     0        S
# 630    male  80.0      0      0     27042  30.0000   A23        S
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Группировка данных
# Pandas также позволяет группировать данные и выполнять агрегирующие операции.

# %%
# Найдите долю выживших среди всех PClass
# Используйте метод .groupby()
table = table.groupby('Pclass')['Survived'].mean()
print(table)
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# ## Часть 4: Задания для практики
# Прочитайте данные из файла 'titanic.csv'.
# Проверьте, есть ли пропущенные значения в данных и заполните их нулями.
# Выведите первые 10 строк данных.
# Выберите только те строки, где значение в столбце 'Age' больше 30.
# Отсортируйте данные по столбцу 'Fare' в порядке убывания.
# Сгруппируйте данные по столбцу 'Pclass' и вычислите средний возраст ('Age') для каждого класса.

# %%
import pandas as pd

table = pd.read_csv('titanic.csv')
print(table.isna)
table = table.fillna(0)
print(table.head(10))
table = table[table['Age'] > 30].sort_values('Fare').groupby('Pclass')['Age'].mean()
print(table)
# Out:
# <bound method DataFrame.isna of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   0.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S
# 5      0            330877   8.4583     0        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750     0        S
# 8      2            347742  11.1333     0        S
# 9      0            237736  30.0708     0        C
# Pclass
# 1    46.196000
# 2    41.694805
# 3    39.883495
# Name: Age, dtype: float64
